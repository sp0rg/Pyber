# %% [markdown]
# # Observations
#
# In all requested charts the Urban 'type' significantly outsized the the other two types (of Rural and Suburban).
#
# While the Rural 'type' had the least amount of drivers (0.8% of total), it did manage to eek out 6.8% of the total fare.
#
# The Suburban 'type' had a similar driver to revenue trend with 12.5% of the total drivers and 30.5% of the total fare.

# %%
#%matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)

# Combine the data into a single dataset
combined_city_ride = pd.merge(ride_data, city_data,
                                 how='outer', on='city')

# Display the data table for preview
combined_city_ride.head(5)
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
#Setting up data frames for bubble plots
#I could do this differently, but am stubbornly trying to do... this
#This thing turned out to be a hot mess

#saving for later - ["type"]index=["Urban","City","Rural"]

#setting up ride counts by city
#urban_ride_count = pd.DataFrame(combined_city_ride.groupby(["city"])["ride_id"].count())
urban_ride_count = pd.DataFrame(combined_city_ride.groupby(["city"])["type"].count())

#setting up average fare by city
urban_avg_fare = pd.DataFrame(combined_city_ride.groupby(["city"])["fare"].mean())

#setting up driver count by city
urban_driver_count = pd.DataFrame(combined_city_ride.groupby(["city"])["driver_count"].count())

urban_ride_count.head()

#was thinking about merging this with the above so that I could
#index off of the type, haven't gotten it to work out yet
#type_by_city = pd.DataFrame(combined_city_ride[["city","type"]])
#type_by_city = pd.DataFrame(combined_city_ride[["city",'type']])
#type_by_city.head()
#["type"],index=['Rural','Suburban','Urban']
# Out:
#                type
# city
# Amandaburgh      18
# Barajasview      22
# Barronchester    16
# Bethanyland      18
# Bradshawfurt     10

# %%
#Just some play-around stuff here
#urban_ride_count = combined_city_ride.groupby(["city"])["ride_id"].count()
#urban_avg_fare = combined_city_ride.groupby(["city"])["fare"].mean()
#type_by_city = pd.DataFrame(combined_city_ride.groupby([["city",'type']]['type'],index=['Rural','Suburban','Urban'])

#my_color=np.random.rand(3)
#my_color=('Urban':'gold', 'City':'lightskyblue','Rural':'lightcoral')

#Setup color scheme
my_color=('gold', 'lightskyblue','lightcoral')
#my_color={'y'}#, 'b','r'}

#Setting up scatter - is not at all accurate by type
plt.scatter(urban_ride_count['type'], urban_avg_fare['fare'], marker="o", c=my_color, s=17*urban_driver_count,edgecolors="black")

#plt.scatter(urban_ride_count, urban_avg_fare, marker="o", facecolors="red", edgecolors="black")

#setting up x and y limits
plt.xlim(0,41)
plt.ylim(17,45)

#Setting up x an y axis
x_axis = np.arange(0,41,5)
y_axis = np.arange(17,45,5)

#adding titles and labels
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.grid(True)
plt.savefig("Pyber_Ride_Share_Bubbles.png")
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
ride_fares = pd.DataFrame(combined_city_ride.groupby(["type"])["fare"].sum(),index=['Rural','Suburban','Urban'])

# Build Pie Chart
plot = ride_fares.plot.pie(y='fare', colors=my_color, autopct="%1.1f%%",figsize=(7,7),startangle=10,shadow=True)

#add Title
plt.title("Total Fares by City Type")

#Save Figure
plt.savefig("Pyber_Total_Fares_by_City.png")
plot

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
ride_totals = pd.DataFrame(combined_city_ride.groupby(["type"])["type"].count(),index=['Rural','Suburban','Urban'])

# Build Pie Chart
plot = ride_totals.plot.pie(y='type',colors=my_color,autopct="%1.1f%%",figsize=(7,7),startangle=10,shadow=True)
plt.title("Total Rides by City Type")

# Save Figure
plt.savefig("Pyber_Total_Ride_by_Type.png")

# %% [markdown]
# ## Total Drivers by City Type

# %%
#This format has issues, notice the axis label
# Calculate Driver Percents
driver_totals = pd.DataFrame(combined_city_ride.groupby(["type"])["driver_count"].sum(),index=['Rural','Suburban','Urban'])

# Build Pie Charts
plot = driver_totals.plot.pie(y='driver_count',colors=my_color,autopct="%1.1f%%",figsize=(7,7),startangle=300,shadow=True)
plt.title("Total Drivers by City Type")

# Save Figure
plt.savefig("Pyber_Total_Drivers_by_City_Type.png")
plot
#driver_totals
